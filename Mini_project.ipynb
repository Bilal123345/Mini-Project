# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilal123345/Mini-Project/blob/main/Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
df=pd.read_csv('/content/ratings_small.csv')

# %%
df.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100004.000000  100004.000000  100004.000000  1.000040e+05
# mean      347.011310   12548.664363       3.543608  1.129639e+09
# std       195.163838   26369.198969       1.058064  1.916858e+08
# min         1.000000       1.000000       0.500000  7.896520e+08
# 25%       182.000000    1028.000000       3.000000  9.658478e+08
# 50%       367.000000    2406.500000       4.000000  1.110422e+09
# 75%       520.000000    5418.000000       4.000000  1.296192e+09
# max       671.000000  163949.000000       5.000000  1.476641e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
df[df['userId'] > 50]
# Out:
#         userId  movieId  rating
# 8033        51      913     4.0
# 8034        51     1636     1.0
# 8035        51     1888     3.0
# 8036        51     1948     4.0
# 8037        51     1959     4.0
# ...        ...      ...     ...
# 99999      671     6268     2.5
# 100000     671     6269     4.0
# 100001     671     6365     4.0
# 100002     671     6385     2.5
# 100003     671     6565     3.5
#
# [91971 rows x 3 columns]

# %%
df.describe()
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %%
Ticketprice=({'Adults': (4000),'Children':(1000)})

# %%
df['Ticketprice']=Ticketprice
print(df)
# Out:
#         userId  movieId  rating  Ticketprice
# 0            1       31     2.5          NaN
# 1            1     1029     3.0          NaN
# 2            1     1061     3.0          NaN
# 3            1     1129     2.0          NaN
# 4            1     1172     4.0          NaN
# ...        ...      ...     ...          ...
# 99999      671     6268     2.5          NaN
# 100000     671     6269     4.0          NaN
# 100001     671     6365     4.0          NaN
# 100002     671     6385     2.5          NaN
# 100003     671     6565     3.5          NaN
#
# [100004 rows x 4 columns]

# %%
df.drop(['Ticketprice','rating'], axis='columns')
# Out:
#         userId  movieId
# 0            1       31
# 1            1     1029
# 2            1     1061
# 3            1     1129
# 4            1     1172
# ...        ...      ...
# 99999      671     6268
# 100000     671     6269
# 100001     671     6365
# 100002     671     6385
# 100003     671     6565
#
# [100004 rows x 2 columns]
